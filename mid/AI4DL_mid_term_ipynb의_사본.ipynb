# %% [markdown]
# <a href="https://colab.research.google.com/github/vowkvns/class_4aidl/blob/main/mid/AI4DL_mid_term_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mid-term exam on AI for Deep Learning
#
# - Name:  김상욱
# - ID Number:  20191955
#
# ------------------------------------------
# Firstly, copy this notebook to your google drive.
# Secondly, click 'Runtime' tab, 'Change runtime type' tab, and change 'Hardware accelerator' as 'GPU.'
# Now you are ready to go, good luck! :)

# %%
import tensorflow as tf
tf.keras.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ## Generating data for the exam

# %%
from sklearn.datasets import make_moons

inputs, targets = make_moons(n_samples=5000, noise=0.1)
inputs_dev, targets_dev = make_moons(n_samples=1000, noise=0.1)

import matplotlib.pyplot as plt
plt.scatter(inputs[:, 0], inputs[:, 1], c=targets)
plt.show()

# %% [markdown]
# ## Q1 We will use the generated data
#
# Inputs and targets are training data, and inputs_dev and targets_dev are validation data.

# %% [markdown]
# #### (Q1-1) [15 points] Check your data and design your neural network model
#   - [5] Check dimension of inputs and targets.
#   - [5] Design a simple model using one hidden dense layer.
#     - Your hidden dense layer have dimension 3 with relu activation
#     - Set the proper activation for binary outcome (0 or 1)
# ![image.png](data:image/png;base64,...)
#   - [5] Build your model and check model summary. The result should look like:
#
#   ![image.png](data:image/png;base64,...)

# %%
## change the code below to check dimension

inputs
# Out:
# array([[ 2.00572276,  0.25012351],
#        [ 1.92878817,  0.44884626],
#        [ 0.87956887, -0.36501619],
#        ...,
#        [ 1.37914689, -0.61651117],
#        [ 0.64777081,  0.69180323],
#        [-0.08418406,  0.84662481]])

# %%
## change the code below to check dimension

targets
# Out:
# array([1, 1, 1, ..., 1, 0, 0])

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
model = models.Sequential(name="sequential_2")
model.add(layers.Dense(3, activation="relu", name="dense_52"))
model.add(layers.Dense(1, activation="sigmoid", name="dense_53"))

# %%
## Build your model, and check the summary. your code here
from tensorflow.keras import models
from tensorflow.keras import layers
model = models.Sequential(name="sequential_2")
model.add(layers.Dense(3, activation="relu", name="dense_52"))
model.add(layers.Dense(1, activation="sigmoid", name="dense_53"))
model.build((None,2))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_52 (Dense)            (None, 3)                 9
#
#  dense_53 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### (Q1-2) [12 points] Compile your model.
#  - [4] Setup optimizer as 'SGD'
#  - [4] Use binary cross entropy loss.
#  - [4] Set your evaluation metric as 'accuracy'

# %%
### Define optimizer, loss, and metrics here
model.compile(optimizer="SGD",
              loss="binary_crossentropy",
              metrics=["accuracy"]
)

# %% [markdown]
# #### (Q1-3) [8 points] Train your model and check results.
#  - [4]  Fit your model using 100 number of epochs with batch size 100. Specify validation data using _inputs_dev_ and _targets_dev_ datasets.
#  - [4] Evaluate your model using _inputs_dev_ and _targets_dev_.

# %%
import numpy as np 



num_validation_samples = 100

val_target =  shuffled_target[:num_validation_samples] 
val_target_dev = shuffled_target_dev[:num_validation_samples]


trn_input = shuffled_inputs[num_validation_samples:]
trn_input_dev = shuffled_inputs_dev[num_validation_samples:]

# %%
history = model.fit(
    inputs, targets, validation_data=(inputs_dev,targets_dev), epochs=100, batch_size=100
          )
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-42-6ae916c87c30> in <cell line: 1>()
# ----> 1 history = model.fit(
#       2     inputs, targets, validation_data=(inputs_dev,targets_dev), epochs=100, batch_size=100
#       3           )
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in _assert_compile_was_called(self)
#    3683         # (i.e. whether the model is built and its inputs/outputs are set).
#    3684         if not self._is_compiled:
# -> 3685             raise RuntimeError(
#    3686                 "You must compile your model before "
#    3687                 "training/testing. "
#
# RuntimeError: You must compile your model before training/testing. Use `model.compile(optimizer, loss)`.

# %%
## Evaluate your model. Your code here:
result = model.evaluate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-caa4b36c8445> in <cell line: 2>()
#       1 ## Evaluate your model. Your code here:
# ----> 2 result = model.evaluate()
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/data_adapter.py in select_data_adapter(x, y)
#    1080     if not adapter_cls:
#    1081         # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1082         raise ValueError(
#    1083             "Failed to find data adapter that can handle input: {}, {}".format(
#    1084                 _type_name(x), _type_name(y)
#
# ValueError: Failed to find data adapter that can handle input: <class 'NoneType'>, <class 'NoneType'>

# %% [markdown]
# #### (Q1-4) [10 points] The current accuracy is not so good. Let's try having nine hidden dense layers to improve the model.
#   - Train and evaluate the model as done before.
#   - Try to visualzie the results.(sample visualization codes provided below)
# ![image.png](data:image/png;base64,...)

# %%
## Plot of the ground truth set
import matplotlib.pyplot as plt
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=targets_dev)
plt.show()

# %%
## Plot of your model
## replace the result with your upgraded model
import matplotlib.pyplot as plt
res1 = model.predict(inputs_dev)
decision1 = res1 > .5
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=decision1)
plt.show()
# Out:
# 32/32 [==============================] - 4s 2ms/step

# %%
model = models.Sequential([
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(3, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# %%
### Define optimizer, loss, and metrics here
model.compile(optimizer="SGD",
              loss="binary_crossentropy",
              metrics=["accuracy"]
)

# %%
history = model.fit(
     inputs, targets, validation_data=(inputs_dev,targets_dev), epochs=100, batch_size=100
          )
# Out:
# Epoch 1/100
# 50/50 [==============================] - 2s 8ms/step - loss: 0.6828 - accuracy: 0.4610 - val_loss: 0.6811 - val_accuracy: 0.4530
# Epoch 2/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6790 - accuracy: 0.5154 - val_loss: 0.6767 - val_accuracy: 0.6280
# Epoch 3/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6741 - accuracy: 0.6512 - val_loss: 0.6710 - val_accuracy: 0.6730
# Epoch 4/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6676 - accuracy: 0.6742 - val_loss: 0.6633 - val_accuracy: 0.7040
# Epoch 5/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6587 - accuracy: 0.7016 - val_loss: 0.6531 - val_accuracy: 0.7160
# Epoch 6/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6476 - accuracy: 0.7092 - val_loss: 0.6409 - val_accuracy: 0.7240
# Epoch 7/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6348 - accuracy: 0.7138 - val_loss: 0.6274 - val_accuracy: 0.7320
# Epoch 8/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.6213 - accuracy: 0.7206 - val_loss: 0.6140 - val_accuracy: 0.7300
# Epoch 9/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.6082 - accuracy: 0.7224 - val_loss: 0.6013 - val_accuracy: 0.7310
# Epoch 10/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5960 - accuracy: 0.7264 - val_loss: 0.5895 - val_accuracy: 0.7230
# Epoch 11/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5842 - accuracy: 0.7278 - val_loss: 0.5778 - val_accuracy: 0.7250
# Epoch 12/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5724 - accuracy: 0.7284 - val_loss: 0.5662 - val_accuracy: 0.7210
# Epoch 13/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.5606 - accuracy: 0.7288 - val_loss: 0.5547 - val_accuracy: 0.7330
# Epoch 14/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5490 - accuracy: 0.7362 - val_loss: 0.5432 - val_accuracy: 0.7410
# Epoch 15/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5375 - accuracy: 0.7424 - val_loss: 0.5319 - val_accuracy: 0.7500
# Epoch 16/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.5261 - accuracy: 0.7464 - val_loss: 0.5206 - val_accuracy: 0.7630
# Epoch 17/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5147 - accuracy: 0.7526 - val_loss: 0.5094 - val_accuracy: 0.7650
# Epoch 18/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.5034 - accuracy: 0.7590 - val_loss: 0.4981 - val_accuracy: 0.7740
# Epoch 19/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4921 - accuracy: 0.7656 - val_loss: 0.4869 - val_accuracy: 0.7800
# Epoch 20/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4811 - accuracy: 0.7710 - val_loss: 0.4762 - val_accuracy: 0.7850
# Epoch 21/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4700 - accuracy: 0.7792 - val_loss: 0.4656 - val_accuracy: 0.7870
# Epoch 22/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.4591 - accuracy: 0.7878 - val_loss: 0.4548 - val_accuracy: 0.7950
# Epoch 23/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4482 - accuracy: 0.7968 - val_loss: 0.4438 - val_accuracy: 0.7990
# Epoch 24/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4371 - accuracy: 0.8032 - val_loss: 0.4331 - val_accuracy: 0.8050
# Epoch 25/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4260 - accuracy: 0.8106 - val_loss: 0.4222 - val_accuracy: 0.8120
# Epoch 26/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4151 - accuracy: 0.8176 - val_loss: 0.4116 - val_accuracy: 0.8190
# Epoch 27/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.4045 - accuracy: 0.8252 - val_loss: 0.4015 - val_accuracy: 0.8250
# Epoch 28/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3939 - accuracy: 0.8326 - val_loss: 0.3921 - val_accuracy: 0.8310
# Epoch 29/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3839 - accuracy: 0.8372 - val_loss: 0.3825 - val_accuracy: 0.8370
# Epoch 30/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3742 - accuracy: 0.8418 - val_loss: 0.3740 - val_accuracy: 0.8390
# Epoch 31/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3652 - accuracy: 0.8466 - val_loss: 0.3659 - val_accuracy: 0.8430
# Epoch 32/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3569 - accuracy: 0.8500 - val_loss: 0.3588 - val_accuracy: 0.8460
# Epoch 33/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3494 - accuracy: 0.8516 - val_loss: 0.3521 - val_accuracy: 0.8480
# Epoch 34/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3424 - accuracy: 0.8548 - val_loss: 0.3455 - val_accuracy: 0.8520
# Epoch 35/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.3361 - accuracy: 0.8578 - val_loss: 0.3399 - val_accuracy: 0.8530
# Epoch 36/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3303 - accuracy: 0.8610 - val_loss: 0.3351 - val_accuracy: 0.8550
# Epoch 37/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3252 - accuracy: 0.8620 - val_loss: 0.3305 - val_accuracy: 0.8570
# Epoch 38/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3202 - accuracy: 0.8614 - val_loss: 0.3261 - val_accuracy: 0.8610
# Epoch 39/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3160 - accuracy: 0.8642 - val_loss: 0.3223 - val_accuracy: 0.8620
# Epoch 40/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3119 - accuracy: 0.8646 - val_loss: 0.3190 - val_accuracy: 0.8600
# Epoch 41/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3084 - accuracy: 0.8664 - val_loss: 0.3159 - val_accuracy: 0.8590
# Epoch 42/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3051 - accuracy: 0.8658 - val_loss: 0.3128 - val_accuracy: 0.8630
# Epoch 43/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.3017 - accuracy: 0.8746 - val_loss: 0.3091 - val_accuracy: 0.8790
# Epoch 44/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2977 - accuracy: 0.8896 - val_loss: 0.3060 - val_accuracy: 0.8920
# Epoch 45/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2939 - accuracy: 0.8992 - val_loss: 0.3035 - val_accuracy: 0.8950
# Epoch 46/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2906 - accuracy: 0.9042 - val_loss: 0.3002 - val_accuracy: 0.9000
# Epoch 47/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2870 - accuracy: 0.9048 - val_loss: 0.2974 - val_accuracy: 0.9000
# Epoch 48/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.2829 - accuracy: 0.9094 - val_loss: 0.2936 - val_accuracy: 0.8960
# Epoch 49/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2777 - accuracy: 0.9094 - val_loss: 0.2875 - val_accuracy: 0.9050
# Epoch 50/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2698 - accuracy: 0.9150 - val_loss: 0.2797 - val_accuracy: 0.8990
# Epoch 51/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.2604 - accuracy: 0.9184 - val_loss: 0.2697 - val_accuracy: 0.9080
# Epoch 52/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2503 - accuracy: 0.9234 - val_loss: 0.2581 - val_accuracy: 0.9190
# Epoch 53/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2390 - accuracy: 0.9294 - val_loss: 0.2445 - val_accuracy: 0.9240
# Epoch 54/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.2248 - accuracy: 0.9368 - val_loss: 0.2301 - val_accuracy: 0.9360
# Epoch 55/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.2091 - accuracy: 0.9438 - val_loss: 0.2134 - val_accuracy: 0.9370
# Epoch 56/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.1945 - accuracy: 0.9482 - val_loss: 0.1964 - val_accuracy: 0.9500
# Epoch 57/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.1796 - accuracy: 0.9560 - val_loss: 0.1807 - val_accuracy: 0.9530
# Epoch 58/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1679 - accuracy: 0.9588 - val_loss: 0.1682 - val_accuracy: 0.9610
# Epoch 59/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1573 - accuracy: 0.9628 - val_loss: 0.1537 - val_accuracy: 0.9680
# Epoch 60/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1475 - accuracy: 0.9682 - val_loss: 0.1440 - val_accuracy: 0.9720
# Epoch 61/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9722 - val_loss: 0.1378 - val_accuracy: 0.9720
# Epoch 62/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1304 - accuracy: 0.9748 - val_loss: 0.1274 - val_accuracy: 0.9790
# Epoch 63/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.1227 - accuracy: 0.9776 - val_loss: 0.1218 - val_accuracy: 0.9790
# Epoch 64/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1160 - accuracy: 0.9792 - val_loss: 0.1210 - val_accuracy: 0.9730
# Epoch 65/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1106 - accuracy: 0.9810 - val_loss: 0.1084 - val_accuracy: 0.9810
# Epoch 66/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.1049 - accuracy: 0.9822 - val_loss: 0.1037 - val_accuracy: 0.9810
# Epoch 67/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0994 - accuracy: 0.9844 - val_loss: 0.0979 - val_accuracy: 0.9820
# Epoch 68/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0940 - accuracy: 0.9854 - val_loss: 0.0928 - val_accuracy: 0.9850
# Epoch 69/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0903 - accuracy: 0.9862 - val_loss: 0.0882 - val_accuracy: 0.9870
# Epoch 70/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0860 - accuracy: 0.9876 - val_loss: 0.0863 - val_accuracy: 0.9880
# Epoch 71/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0828 - accuracy: 0.9888 - val_loss: 0.0842 - val_accuracy: 0.9870
# Epoch 72/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.9904 - val_loss: 0.0787 - val_accuracy: 0.9910
# Epoch 73/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0768 - accuracy: 0.9906 - val_loss: 0.0757 - val_accuracy: 0.9900
# Epoch 74/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0736 - accuracy: 0.9914 - val_loss: 0.0718 - val_accuracy: 0.9910
# Epoch 75/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9920 - val_loss: 0.0691 - val_accuracy: 0.9920
# Epoch 76/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0678 - accuracy: 0.9916 - val_loss: 0.0761 - val_accuracy: 0.9870
# Epoch 77/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0659 - accuracy: 0.9934 - val_loss: 0.0643 - val_accuracy: 0.9920
# Epoch 78/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0643 - accuracy: 0.9932 - val_loss: 0.0617 - val_accuracy: 0.9920
# Epoch 79/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0615 - accuracy: 0.9936 - val_loss: 0.0616 - val_accuracy: 0.9920
# Epoch 80/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0596 - accuracy: 0.9942 - val_loss: 0.0581 - val_accuracy: 0.9930
# Epoch 81/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0579 - accuracy: 0.9932 - val_loss: 0.0554 - val_accuracy: 0.9960
# Epoch 82/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9942 - val_loss: 0.0576 - val_accuracy: 0.9920
# Epoch 83/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 0.9954 - val_loss: 0.0533 - val_accuracy: 0.9930
# Epoch 84/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0531 - accuracy: 0.9944 - val_loss: 0.0575 - val_accuracy: 0.9920
# Epoch 85/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0515 - accuracy: 0.9950 - val_loss: 0.0498 - val_accuracy: 0.9970
# Epoch 86/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0508 - accuracy: 0.9946 - val_loss: 0.0483 - val_accuracy: 0.9970
# Epoch 87/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9952 - val_loss: 0.0486 - val_accuracy: 0.9980
# Epoch 88/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0482 - accuracy: 0.9950 - val_loss: 0.0466 - val_accuracy: 0.9970
# Epoch 89/100
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0460 - accuracy: 0.9950 - val_loss: 0.0440 - val_accuracy: 0.9980
# Epoch 90/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0452 - accuracy: 0.9954 - val_loss: 0.0439 - val_accuracy: 0.9980
# Epoch 91/100
# 50/50 [==============================] - 0s 6ms/step - loss: 0.0440 - accuracy: 0.9952 - val_loss: 0.0422 - val_accuracy: 0.9980
# Epoch 92/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9960 - val_loss: 0.0416 - val_accuracy: 0.9980
# Epoch 93/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0424 - accuracy: 0.9958 - val_loss: 0.0396 - val_accuracy: 0.9980
# Epoch 94/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0420 - accuracy: 0.9964 - val_loss: 0.0414 - val_accuracy: 0.9980
# Epoch 95/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0396 - accuracy: 0.9962 - val_loss: 0.0384 - val_accuracy: 0.9980
# Epoch 96/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0399 - accuracy: 0.9962 - val_loss: 0.0394 - val_accuracy: 0.9980
# Epoch 97/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0383 - accuracy: 0.9964 - val_loss: 0.0398 - val_accuracy: 0.9980
# Epoch 98/100
# 50/50 [==============================] - 0s 8ms/step - loss: 0.0375 - accuracy: 0.9966 - val_loss: 0.0377 - val_accuracy: 0.9980
# Epoch 99/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9964 - val_loss: 0.0343 - val_accuracy: 0.9990
# Epoch 100/100
# 50/50 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 0.9966 - val_loss: 0.0341 - val_accuracy: 0.9980

# %%
## Plot of the ground truth set
import matplotlib.pyplot as plt
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=targets_dev)
plt.show()

# %%
## Plot of your new model
import matplotlib.pyplot as plt
res1 = model.predict(inputs_dev)
decision1 = res1 > .5
plt.scatter(inputs_dev[:, 0], inputs_dev[:, 1], c=decision1)
plt.show()

# %% [markdown]
# ## Q2 We will use the Boston housing data for Q2

# %%
from tensorflow.keras.datasets import boston_housing
(train_data, train_targets), (test_data, test_targets) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %%
mean = train_data.mean(axis=0)
train_data -= mean
std = train_data.std(axis=0)
train_data /= std
test_data -= mean
test_data /= std

# %%
train_data.shape
# Out:
# (404, 13)

# %%
import numpy as np 

indices_permutation = np.random.permutation(404)
shuffled_x_train = train_data[indices_permutation]
shuffled_train_targets = train_targets[indices_permutation]

num_validation_samples = 54

## Complete the code below: 
val_x = shuffled_x_train[:54] ## take first 54 samples of shuffled_x_train 
val_targets = shuffled_train_targets[:54] ## take first 54 samples of shuffled_train_targets 


trn_x = shuffled_x_train[num_validation_samples:]
trn_targets = shuffled_train_targets[num_validation_samples:]

# %% [markdown]
# #### (Q2-1) [16 points] Design your neural network model with the structure below
#
# - We have two hidden Dense layers and one output layer as described below.
#   - [4] Try to make your model using functional API
#   - [4] Setup output sizes as 10 and 10 for hidden dense layers with relu activation.
#   - [4] Setup appropriate output dense layer for this regression problem.
#   - [4] For compile your model, let's use the RMSprop optimizer and specify the MSE as the loss function. For evaluation metrics, let's use MAE and MSE.
#
# ![image.png](data:image/png;base64,...)

# %%
trn_x.shape
# Out:
# (350, 13)

# %%
from tensorflow import keras
from tensorflow.keras import layers
  
# define your model here using Functional API 
inputs = keras.Input(shape=(3,), name="my_input")
features = layers.Dense(10, activation="relu")(inputs)
features = layers.Dense(10, activation="relu")(features)
outputs = layers.Dense(10, activation="softmax")(features)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer="rmsprop",
              loss=["mean_squared_error"],
              metrics=[["mean_absolute_error"], [["mean_squared_error"]]]
)

# %% [markdown]
# #### (Q2-2) [16 points] Fit your model.
# - [4] Use epoch size of 100, and batch size of 50.
# - [4] Use trn_x and trn_targets as training data
# - [4] Use val_x and val_targets as validation data
# - [4] Use ModelCheckpoint callback. Save the best one with respect to validation MAE.

# %%
## Define your callback here
callbacks_list = [
    keras.callbacks.ModelCheckpoint(
        filepath="checkpoint_path.keras",
        monitor="mean_absolute_error",
        save_best_only=True,
    )
]

## fit your model
history = model.fit(
    trn_x, trn_targets, validation_data=(val_x, val_targets), epochs=100, batch_size=50
    )
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 37ms/step - loss: 584.4730 - mae: 22.1684 - mse: 584.4730 - val_loss: 525.0997 - val_mae: 21.3022 - val_mse: 525.0997
# Epoch 2/100
# 7/7 [==============================] - 0s 11ms/step - loss: 577.5428 - mae: 21.9656 - mse: 577.5430 - val_loss: 519.0368 - val_mae: 21.1223 - val_mse: 519.0368
# Epoch 3/100
# 7/7 [==============================] - 0s 10ms/step - loss: 572.0711 - mae: 21.8069 - mse: 572.0711 - val_loss: 513.4191 - val_mae: 20.9542 - val_mse: 513.4191
# Epoch 4/100
# 7/7 [==============================] - 0s 13ms/step - loss: 566.6658 - mae: 21.6491 - mse: 566.6658 - val_loss: 507.8156 - val_mae: 20.7864 - val_mse: 507.8156
# Epoch 5/100
# 7/7 [==============================] - 0s 10ms/step - loss: 561.0650 - mae: 21.4859 - mse: 561.0650 - val_loss: 502.1995 - val_mae: 20.6165 - val_mse: 502.1995
# Epoch 6/100
# 7/7 [==============================] - 0s 13ms/step - loss: 555.2145 - mae: 21.3192 - mse: 555.2145 - val_loss: 496.4264 - val_mae: 20.4391 - val_mse: 496.4264
# Epoch 7/100
# 7/7 [==============================] - 0s 13ms/step - loss: 549.2328 - mae: 21.1401 - mse: 549.2328 - val_loss: 490.5702 - val_mae: 20.2553 - val_mse: 490.5702
# Epoch 8/100
# 7/7 [==============================] - 0s 13ms/step - loss: 543.2231 - mae: 20.9642 - mse: 543.2231 - val_loss: 484.5447 - val_mae: 20.0652 - val_mse: 484.5447
# Epoch 9/100
# 7/7 [==============================] - 0s 13ms/step - loss: 537.0762 - mae: 20.7836 - mse: 537.0762 - val_loss: 478.2799 - val_mae: 19.8624 - val_mse: 478.2799
# Epoch 10/100
# 7/7 [==============================] - 0s 14ms/step - loss: 530.8389 - mae: 20.5937 - mse: 530.8389 - val_loss: 471.9979 - val_mae: 19.6551 - val_mse: 471.9979
# Epoch 11/100
# 7/7 [==============================] - 0s 13ms/step - loss: 524.5481 - mae: 20.4103 - mse: 524.5481 - val_loss: 465.6586 - val_mae: 19.4411 - val_mse: 465.6586
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 518.2075 - mae: 20.2204 - mse: 518.2075 - val_loss: 459.1769 - val_mae: 19.2329 - val_mse: 459.1769
# Epoch 13/100
# 7/7 [==============================] - 0s 11ms/step - loss: 511.6395 - mae: 20.0207 - mse: 511.6396 - val_loss: 452.4620 - val_mae: 19.0462 - val_mse: 452.4620
# Epoch 14/100
# 7/7 [==============================] - 0s 10ms/step - loss: 504.8600 - mae: 19.8177 - mse: 504.8600 - val_loss: 445.6310 - val_mae: 18.8515 - val_mse: 445.6310
# Epoch 15/100
# 7/7 [==============================] - 0s 10ms/step - loss: 497.9800 - mae: 19.6164 - mse: 497.9800 - val_loss: 438.6701 - val_mae: 18.6491 - val_mse: 438.6701
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 490.9128 - mae: 19.4136 - mse: 490.9128 - val_loss: 431.5584 - val_mae: 18.4361 - val_mse: 431.5584
# Epoch 17/100
# 7/7 [==============================] - 0s 11ms/step - loss: 483.7355 - mae: 19.2058 - mse: 483.7355 - val_loss: 424.3715 - val_mae: 18.2163 - val_mse: 424.3715
# Epoch 18/100
# 7/7 [==============================] - 0s 10ms/step - loss: 476.4066 - mae: 18.9998 - mse: 476.4066 - val_loss: 417.1082 - val_mae: 17.9924 - val_mse: 417.1082
# Epoch 19/100
# 7/7 [==============================] - 0s 10ms/step - loss: 468.9152 - mae: 18.7956 - mse: 468.9152 - val_loss: 409.7283 - val_mae: 17.7584 - val_mse: 409.7283
# Epoch 20/100
# 7/7 [==============================] - 0s 13ms/step - loss: 461.2722 - mae: 18.5789 - mse: 461.2722 - val_loss: 402.1329 - val_mae: 17.5117 - val_mse: 402.1329
# Epoch 21/100
# 7/7 [==============================] - 0s 14ms/step - loss: 453.4027 - mae: 18.3700 - mse: 453.4027 - val_loss: 394.4176 - val_mae: 17.2592 - val_mse: 394.4176
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 445.3470 - mae: 18.1547 - mse: 445.3470 - val_loss: 386.6365 - val_mae: 17.0023 - val_mse: 386.6365
# Epoch 23/100
# 7/7 [==============================] - 0s 12ms/step - loss:
# Epoch 92/100
# 7/7 [==============================] - 0s 11ms/step - loss: 16.0403 - mae: 2.7698 - mse: 16.0403 - val_loss: 16.1839 - val_mae: 3.3747 - val_mse: 16.1839
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 15.8883 - mae: 2.7668 - mse: 15.8883 - val_loss: 15.9091 - val_mae: 3.3470 - val_mse: 15.9091
# Epoch 94/100
# 7/7 [==============================] - 0s 13ms/step - loss: 15.6921 - mae: 2.7495 - mse: 15.6921 - val_loss: 15.6597 - val_mae: 3.3223 - val_mse: 15.6597
# Epoch 95/100
# 7/7 [==============================] - 0s 13ms/step - loss: 15.5190 - mae: 2.7491 - mse: 15.5190 - val_loss: 15.4920 - val_mae: 3.3031 - val_mse: 15.4920
# Epoch 96/100
# 7/7 [==============================] - 0s 10ms/step - loss: 15.4262 - mae: 2.7361 - mse: 15.4262 - val_loss: 15.3605 - val_mae: 3.2898 - val_mse: 15.3605
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 15.2367 - mae: 2.7241 - mse: 15.2367 - val_loss: 15.0633 - val_mae: 3.2609 - val_mse: 15.0633
# Epoch 98/100
# 7/7 [==============================] - 0s 12ms/step - loss: 15.0876 - mae: 2.7150 - mse: 15.0876 - val_loss: 14.8661 - val_mae: 3.2382 - val_mse: 14.8661
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 14.9119 - mae: 2.7029 - mse: 14.9119 - val_loss: 14.7421 - val_mae: 3.2245 - val_mse: 14.7421
# Epoch 100/100
# 7/7 [==============================] - 0s 13ms/step - loss: 14.7702 - mae: 2.6872 - mse: 14.7702 - val_loss: 14.6192 - val_mae: 3.2145 - val_mse: 14.6192

# %%
## Visualizing training result
import matplotlib.pyplot as plt
val_loss = history.history["val_mae"]
trn_loss = history.history["mae"]
epochs = range(1, 101)
plt.plot(epochs, val_loss, "b--",
         label="Validation MAE")
plt.plot(epochs, trn_loss, "r-",
         label="Training MAE")
plt.title("MAE")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.ylim([1,25])
plt.legend()

# %% [markdown]
# #### (Q2-3) [8 points] Load the best model from your callback checkpoint. Evaluate your model on test data.
# - [4] Load the best model from your ModelCheckpoint callback
# - [4] Report the MAE and MSE score on test data

# %%
## Load the best model, and use model.evaluate to get MAE and MSE scores.
model = keras.models.load_model("checkpoint_path.keras")
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 14.6192 - mae: 3.2145 - mse: 14.6192
# [14.619190216064453, 3.2145063877105713, 14.619190216064453]

# %% [markdown]
# #### (Q2-4) [15 points] Assuming that you have the Boston housing prices from 5 years ago, we have generated a fake dataset as below.

# %%
## house price 5 years ago
trn_price_5years_ago = trn_targets - 5 + np.random.random(len(trn_targets))*5 
val_price_5years_ago = val_targets - 5 + np.random.random(len(val_targets))*5

# %% [markdown]
# We would like to create a multi-input model with 'Boston housing prices from 5 years ago' as input2. Try to make your model as below.
#
# ![image.png](data:image/png;base64,...)

# %%
from tensorflow import keras
from tensorflow.keras import layers

## Your model here


## Compile your model
model.compile()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  my_input (InputLayer)          [(None, 13)]         0           []
#
#  dense_72 (Dense)               (None, 10)           140         ['my_input[0][0]']
#
#  dense_73 (Dense)               (None, 10)           110         ['dense_72[0][0]']
#
#  my_input2 (InputLayer)         [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 11)           0           ['dense_73[0][0]',
#                                                                   'my_input2[0][0]']
#
#  dense_74 (Dense)               (None, 1)            12          ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 262
# Trainable params: 262
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
## Your model may look like this.
keras.utils.plot_model(model, "model2.png", show_shapes=True)

# %%
## Fit your model 
    ## Specify training data, validation data

history = model.fit(##Specify training data ,
                    trn_targets,
                    epochs=100,
                    batch_size=50,
                    ##Specify validation data
    )
# Out:
# Epoch 1/100
# 7/7 [==============================] - 2s
# Epoch 52/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.5984 - mae: 1.4978 - mse: 3.5984 - val_loss: 4.4299 - val_mae: 1.8191 - val_mse: 4.4299
# Epoch 53/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4066 - mae: 1.4646 - mse: 3.4066 - val_loss: 4.1914 - val_mae: 1.7755 - val_mse: 4.1914
# Epoch 54/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.2293 - mae: 1.4283 - mse: 3.2293 - val_loss: 3.9956 - val_mae: 1.7414 - val_mse: 3.9956
# Epoch 55/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.0718 - mae: 1.3981 - mse: 3.0718 - val_loss: 3.8160 - val_mae: 1.7102 - val_mse: 3.8160
# Epoch 56/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.9340 - mae: 1.3690 - mse: 2.9340 - val_loss: 3.6635 - val_mae: 1.6825 - val_mse: 3.6635
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.8090 - mae: 1.3464 - mse: 2.8090 - val_loss: 3.5213 - val_mae: 1.6552 - val_mse: 3.5213
# Epoch 58/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.7094 - mae: 1.3307 - mse: 2.7094 - val_loss: 3.3968 - val_mae: 1.6307 - val_mse: 3.3968
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.6082 - mae: 1.3052 - mse: 2.6082 - val_loss: 3.2837 - val_mae: 1.6064 - val_mse: 3.2837
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2.5235 - mae: 1.2867 - mse: 2.5235 - val_loss: 3.1810 - val_mae: 1.5819 - val_mse: 3.1810
# Epoch 61/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.4467 - mae: 1.2668 - mse: 2.4467 - val_loss: 3.0977 - val_mae: 1.5583 - val_mse: 3.0977
# Epoch 62/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2.3839 - mae: 1.2520 - mse: 2.3839 - val_loss: 3.0215 - val_mae: 1.5406 - val_mse: 3.0215
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2.3242 - mae: 1.2386 - mse: 2.3242 - val_loss: 2.9549 - val_mae: 1.5233 - val_mse: 2.9549
# Epoch 64/100
# 7/7 [==============================] - 0s 11ms/step - loss: 2.2681 - mae: 1.2253 - mse: 2.2681 - val_loss: 2.9052 - val_mae: 1.5127 - val_mse: 2.9052
# Epoch 65/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.2331 - mae: 1.2220 - mse: 2.2331 - val_loss: 2.8514 - val_mae: 1.4926 - val_mse: 2.8514
# Epoch 66/100
# 7/7 [==============================] - 0s 16ms/step - loss: 2.2040 - mae: 1.2179 - mse: 2.2040 - val_loss: 2.8186 - val_mae: 1.4825 - val_mse: 2.8186
# Epoch 67/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1705 - mae: 1.2075 - mse: 2.1705 - val_loss: 2.7864 - val_mae: 1.4734 - val_mse: 2.7864
# Epoch 68/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1381 - mae: 1.1971 - mse: 2.1381 - val_loss: 2.7579 - val_mae: 1.4656 - val_mse: 2.7579
# Epoch 69/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1180 - mae: 1.1943 - mse: 2.1180 - val_loss: 2.7357 - val_mae: 1.4587 - val_mse: 2.7357
# Epoch 70/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.1070 - mae: 1.1899 - mse: 2.1070 - val_loss: 2.7082 - val_mae: 1.4486 - val_mse: 2.7082
# Epoch 71/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0918 - mae: 1.1915 - mse: 2.0918 - val_loss: 2.6989 - val_mae: 1.4477 - val_mse: 2.6989
# Epoch 72/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0682 - mae: 1.1832 - mse: 2.0682 - val_loss: 2.6783 - val_mae: 1.4410 - val_mse: 2.6783
# Epoch 73/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0521 - mae: 1.1809 - mse: 2.0521 - val_loss: 2.6651 - val_mae: 1.4384 - val_mse: 2.6651
# Epoch 74/100
# 7/7 [==============================] - 0s 15ms/step - loss: 2.0428 - mae: 1.1819 - mse: 2.0428 - val_loss: 2.6622 - val_mae: 1.4423 - val_mse: 2.6622
# Epoch 75/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.0382 - mae: 1.1789 - mse: 2.0382 - val_loss: 2.6468 - val_mae: 1.4365 - val_mse: 2.6468
# Epoch 76/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0221 - mae: 1.1737 - mse: 2.0221 - val_loss: 2.6323 - val_mae: 1.4288 - val_mse: 2.6323
# Epoch 77/100
# 7/7 [==============================] - 0s 14ms/step - loss: 2.0105 - mae: 1.1732 - mse: 2.0105 - val_loss: 2.6280 - val_mae: 1.4311 - val_mse: 2.6280
# Epoch 78/100
# 7/7 [==============================] - 0s 13ms/step - loss: 2.0052 - mae: 1.1689 - mse: 2.0052 - val_loss: 2.6215 - val_mae: 1.4277 - val_mse: 2.6215
# Epoch 79/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9907 - mae: 1.1690 - mse: 1.9907 - val_loss: 2.6202 - val_mae: 1.4300 - val_mse: 2.6202
# Epoch 80/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9937 - mae: 1.1675 - mse: 1.9937 - val_loss: 2.6205 - val_mae: 1.4326 - val_mse: 2.6205
# Epoch 81/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9837 - mae: 1.1663 - mse: 1.9837 - val_loss: 2.6022 - val_mae: 1.4251 - val_mse: 2.6022
# Epoch 82/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9713 - mae: 1.1653 - mse: 1.9713 - val_loss: 2.5906 - val_mae: 1.4200 - val_mse: 2.5906
# Epoch 83/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9658 - mae: 1.1630 - mse: 1.9658 - val_loss: 2.5963 - val_mae: 1.4241 - val_mse: 2.5963
# Epoch 84/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9523 - mae: 1.1600 - mse: 1.9523 - val_loss: 2.5928 - val_mae: 1.4243 - val_mse: 2.5928
# Epoch 85/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1.9557 - mae: 1.1611 - mse: 1.9557 - val_loss: 2.5919 - val_mae: 1.4224 - val_mse: 2.5919
# Epoch 86/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9396 - mae: 1.1581 - mse: 1.9396 - val_loss: 2.5848 - val_mae: 1.4177 - val_mse: 2.5848
# Epoch 87/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1.9412 - mae: 1.1591 - mse: 1.9412 - val_loss: 2.5726 - val_mae: 1.4143 - val_mse: 2.5726
# Epoch 88/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.9265 - mae: 1.1544 - mse: 1.9265 - val_loss: 2.5693 - val_mae: 1.4142 - val_mse: 2.5693
# Epoch 89/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9198 - mae: 1.1524 - mse: 1.9198 - val_loss: 2.5585 - val_mae: 1.4090 - val_mse: 2.5585
# Epoch 90/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.9129 - mae: 1.1496 - mse: 1.9129 - val_loss: 2.5497 - val_mae: 1.4081 - val_mse: 2.5497
# Epoch 91/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9122 - mae: 1.1509 - mse: 1.9122 - val_loss: 2.5588 - val_mae: 1.4107 - val_mse: 2.5588
# Epoch 92/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.9080 - mae: 1.1511 - mse: 1.9080 - val_loss: 2.5563 - val_mae: 1.4129 - val_mse: 2.5563
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.9065 - mae: 1.1538 - mse: 1.9065 - val_loss: 2.5581 - val_mae: 1.4141 - val_mse: 2.5581
# Epoch 94/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.8950 - mae: 1.1477 - mse: 1.8950 - val_loss: 2.5448 - val_mae: 1.4073 - val_mse: 2.5448
# Epoch 95/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8958 - mae: 1.1452 - mse: 1.8958 - val_loss: 2.5354 - val_mae: 1.4043 - val_mse: 2.5354
# Epoch 96/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8799 - mae: 1.1441 - mse: 1.8799 - val_loss: 2.5469 - val_mae: 1.4112 - val_mse: 2.5469
# Epoch 97/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.8820 - mae: 1.1432 - mse: 1.8820 - val_loss: 2.5493 - val_mae: 1.4100 - val_mse: 2.5493
# Epoch 98/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.8746 - mae: 1.1413 - mse: 1.8746 - val_loss: 2.5310 - val_mae: 1.3968 - val_mse: 2.5310
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.8714 - mae: 1.1415 - mse: 1.8714 - val_loss: 2.5334 - val_mae: 1.4069 - val_mse: 2.5334
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.8663 - mae: 1.1402 - mse: 1.8663 - val_loss: 2.5280 - val_mae: 1.4006 - val_mse: 2.5280

# %%
import matplotlib.pyplot as plt
val_loss = history.history["val_mae"]
trn_loss = history.history["mae"]
epochs = range(1, 101)
plt.plot(epochs, val_loss, "b--",
         label="Validation MAE")
plt.plot(epochs, trn_loss, "r-",
         label="Training MAE")
plt.title("MAE")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.ylim([1,25])
plt.legend()
